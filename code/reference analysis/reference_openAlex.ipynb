# %% [markdown]
# #### Step 1 导入相关包

# %%
import pandas as pd 
import requests
import numpy as np
from collections import defaultdict
from tqdm import tqdm
import openpyxl
import string
import pickle

# %% [markdown]
# #### Step 2 加载数据

# %%
with open('rest_paper_id.pickle','rb') as file:
    rest_paper_id = pickle.load(file)

# %%
rest_paper_id
# Out:
# ['2020.acl-demos.1',
#  '2020.acl-demos.10',
#  '2020.acl-demos.11',
#  '2020.acl-demos.12',
#  '2020.acl-demos.13',
#  '2020.acl-demos.14',
#  '2020.acl-demos.15',
#  '2020.acl-demos.16',
#  '2020.acl-demos.17',
#  '2020.acl-demos.18',
#  '2020.acl-demos.19',
#  '2020.acl-demos.2',
#  '2020.acl-demos.20',
#  '2020.acl-demos.21',
#  '2020.acl-demos.22',
#  '2020.acl-demos.23',
#  '2020.acl-demos.24',
#  '2020.acl-demos.25',
#  '2020.acl-demos.26',
#  '2020.acl-demos.27',
#  '2020.acl-demos.28',
#  '2020.acl-demos.29',
#  '2020.acl-demos.3',
#  '2020.acl-demos.30',
#  '2020.acl-demos.31',
#  '2020.acl-demos.32',
#  '2020.acl-demos.33',
#  '2020.acl-demos.34',
#  '2020.acl-demos.35',
#  '2020.acl-demos.36',
#  '2020.acl-demos.37',
#  '2020.acl-demos.38',
#  '2020.acl-demos.39',
#  '2020.acl-demos.4',
#  '2020.acl-demos.40',
#  '2020.acl-demos.41',
#  '2020.acl-demos.42',
#  '2020.acl-demos.43',
#  '2020.acl-demos.5',
#  '2020.acl-demos.6',
#  '2020.acl-demos.7',
#  '2020.acl-demos.8',
#  '2020.acl-demos.9',
#  '2020.acl-main.563',
#  '2020.acl-main.69',
#  '2020.acl-srw.1',
#  '2020.acl-srw.10',
#  '2020.acl-srw.11',
#  '2020.acl-srw.12',
#  '2020.acl-srw.13',
#  '2020.acl-srw.14',
#  '2020.acl-srw.15',
#  '2020.acl-srw.16',
#  '2020.acl-srw.17',
#  '2020.acl-srw.18',
#  '2020.acl-srw.19',
#  '2020.acl-srw.2',
#  '2020.acl-srw.20',
#  '2020.acl-srw.22',
#  '2020.acl-srw.23',
#  '2020.acl-srw.24',
#  '2020.acl-srw.25',
#  '2020.acl-srw.26',
#  '2020.acl-srw.27',
#  '2020.acl-srw.28',
#  '2020.acl-srw.29',
#  '2020.acl-srw.3',
#  '2020.acl-srw.30',
#  '2020.acl-srw.31',
#  '2020.acl-srw.32',
#  '2020.acl-srw.33',
#  '2020.acl-srw.34',
#  '2020.acl-srw.35',
#  '2020.acl-srw.36',
#  '2020.acl-srw.37',
#  '2020.acl-srw.38',
#  '2020.acl-srw.39',
#  '2020.acl-srw.4',
#  '2020.acl-srw.40',
#  '2020.acl-srw.41',
#  '2020.acl-srw.42',
#  '2020.acl-srw.43',
#  '2020.acl-srw.5',
#  '2020.acl-srw.6',
#  '2020.acl-srw.7',
#  '2020.acl-srw.8',
#  '2020.acl-srw.9',
#  '2020.acl-tutorials.1',
#  '2020.acl-tutorials.2',
#  '2020.acl-tutorials.3',
#  '2020.acl-tutorials.4',
#  '2020.acl-tutorials.5',
#  '2020.acl-tutorials.6',
#  '2020.acl-tutorials.7',
#  '2021.acl-demo.1',
#  '2021.acl-demo.10',
#  '2021.acl-demo.11',
#  '2021.acl-demo.12',
#  '2021.acl-demo.13',
#  '2021.acl-demo.14',
#  '2021.acl-demo.15',
#  '2021.acl-demo.16',
#  '2021.acl-demo.17',
#  '2021.acl-demo.18',
#  '2021.acl-demo.19',
#  '2021.acl-demo.2',
#  '2021.acl-demo.20',
#  '2021.acl-demo.21',
#  '2021.acl-demo.22',
#  '2021.acl-demo.23',
#  '2021.acl-demo.24',
#  '2021.acl-demo.25',
#  '2021.acl-demo.26',
#  '2021.acl-demo.27',
#  '2021.acl-demo.28',
#  '2021.acl-demo.29',
#  '2021.acl-demo.3',
#  '2021.acl-demo.30',
#  '2021.acl-demo.31',
#  '2021.acl-demo.32',
#  '2021.acl-demo.33',
#  '2021.acl-demo.34',
#  '2021.acl-demo.35',
#  '2021.acl-demo.36',
#  '2021.acl-demo.37',
#  '2021.acl-demo.38',
#  '2021.acl-demo.39',
#  '2021.acl-demo.4',
#  '2021.acl-demo.40',
#  '2021.acl-demo.41',
#  '2021.acl-demo.42',
#  '2021.acl-demo.43',
#  '2021.acl-demo.5',
#  '2021.acl-demo.6',
#  '2021.acl-demo.7',
#  '2021.acl-demo.8',
#  '2021.acl-demo.9',
#  '2021.acl-long.485',
#  '2021.acl-long.79',
#  '2021.acl-short.29',
#  '2021.acl-srw.1',
#  '2021.acl-srw.10',
#  '2021.acl-srw.11',
#  '2021.acl-srw.12',
#  '2021.acl-srw.13',
#  '2021.acl-srw.14',
#  '2021.acl-srw.15',
#  '2021.acl-srw.16',
#  '2021.acl-srw.17',
#  '2021.acl-srw.18',
#  '2021.acl-srw.19',
#  '2021.acl-srw.2',
#  '2021.acl-srw.20',
#  '2021.acl-srw.21',
#  '2021.acl-srw.22',
#  '2021.acl-srw.23',
#  '2021.acl-srw.24',
#  '2021.acl-srw.25',
#  '2021.acl-srw.26',
#  '2021.acl-srw.27',
#  '2021.acl-srw.28',
#  '2021.acl-srw.29',
#  '2021.acl-srw.3',
#  '2021.acl-srw.30',
#  '2021.acl-srw.31',
#  '2021.acl-srw.32',
#  '2021.acl-srw.33',
#  '2021.acl-srw.34',
#  '2021.acl-srw.35',
#  '2021.acl-srw.36',
#  '2021.acl-srw.4',
#  '2021.acl-srw.5',
#  '2021.acl-srw.6',
#  '2021.acl-srw.7',
#  '2021.acl-srw.8',
#  '2021.acl-srw.9',
#  '2021.acl-tutorials.1',
#  '2021.acl-tutorials.2',
#  '2021.acl-tutorials.3',
#  '2021.acl-tutorials.4',
#  '2021.acl-tutorials.6',
#  '2022.acl-demo.1',
#  '2022.acl-demo.10',
#  '2022.acl-demo.11',
#  '2022.acl-demo.12',
#  '2022.acl-demo.13',
#  '2022.acl-demo.14',
#  '2022.acl-demo.15',
#  '2022.acl-demo.16',
#  '2022.acl-demo.17',
#  '2022.acl-demo.18',
#  '2022.acl-demo.19',
#  '2022.acl-demo.2',
#  '2022.acl-demo.20',
#  '2022.acl-demo.21',
#  '2022.acl-demo.22',
#  '2022.acl-demo.23',
#  '2022.acl-demo.24',
#  '2022.acl-demo.25',
#  '2022.acl-demo.26',
#  '2022.acl-demo.27',
#  '2022.acl-demo.3',
#  '2022.acl-demo.4',
#  '2022.acl-demo.5',
#  '2022.acl-demo.6',
#  '2022.acl-demo.7',
#  '2022.acl-demo.8',
#  '2022.acl-demo.9',
#  '2022.acl-long.1',
#  '2022.acl-long.10',
#  '2022.acl-long.100',
#  '2022.acl-long.101',
#  '2022.acl-long.102',
#  '2022.acl-long.103',
#  '2022.acl-long.104',
#  '2022.acl-long.105',
#  '2022.acl-long.106',
#  '2022.acl-long.107',
#  '2022.acl-long.108',
#  '2022.acl-long.109',
#  '2022.acl-long.11',
#  '2022.acl-long.110',
#  '2022.acl-long.111',
#  '2022.acl-long.112',
#  '2022.acl-long.113',
#  '2022.acl-long.114',
#  '2022.acl-long.115',
#  '2022.acl-long.116',
#  '2022.acl-long.117',
#  '2022.acl-long.118',
#  '2022.acl-long.119',
#  '2022.acl-long.12',
#  '2022.acl-long.120',
#  '2022.acl-long.121',
#  '2022.acl-long.122',
#  '2022.acl-long.123',
#  '2022.acl-long.124',
#  '2022.acl-long.125',
#  '2022.acl-long.126',
#  '2022.acl-long.127',
#  '2022.acl-long.128',
#  '2022.acl-long.129',
#  '2022.acl-long.13',
#  '2022.acl-long.130',
#  '2022.acl-long.131',
#  '2022.acl-long.132',
#  '2022.acl-long.133',
#  '2022.acl-long.134',
#  '2022.acl-long.135',
#  '2022.acl-long.136',
#  '2022.acl-long.137',
#  '2022.acl-long.138',
#  '2022.acl-long.139',
#  '2022.acl-long.14',
#  '2022.acl-long.140',
#  '2022.acl-long.141',
#  '2022.acl-long.142',
#  '2022.acl-long.143',
#  '2022.acl-long.144',
#  '2022.acl-long.145',
#  '2022.acl-long.146',
#  '2022.acl-long.147',
#  '2022.acl-long.148',
#  '2022.acl-long.149',
#  '2022.acl-long.15',
#  '2022.acl-long.150',
#  '2022.acl-long.151',
#  '2022.acl-long.152',
#  '2022.acl-long.153',
#  '2022.acl-long.154',
#  '2022.acl-long.155',
#  '2022.acl-long.156',
#  '2022.acl-long.157',
#  '2022.acl-long.158',
#  '2022.acl-long.159',
#  '2022.acl-long.16',
#  '2022.acl-long.160',
#  '2022.acl-long.161',
#  '2022.acl-long.162',
#  '2022.acl-long.163',
#  '2022.acl-long.164',
#  '2022.acl-long.165',
#  '2022.acl-long.166',
#  '2022.acl-long.167',
#  '2022.acl-long.168',
#  '2022.acl-long.169',
#  '2022.acl-long.17',
#  '2022.acl-long.170',
#  '2022.acl-long.171',
#  '2022.acl-long.172',
#  '2022.acl-long.173',
#  '2022.acl-long.174',
#  '2022.acl-long.175',
#  '2022.acl-long.176',
#  '2022.acl-long.177',
#  '2022.acl-long.178',
#  '2022.acl-long.18',
#  '2022.acl-long.180',
#  '2022.acl-long.181',
#  '2022.acl-long.182',
#  '2022.acl-long.183',
#  '2022.acl-long.184',
#  '2022.acl-long.185',
#  '2022.acl-long.186',
#  '2022.acl-long.187',
#  '2022.acl-long.188',
#  '2022.acl-long.189',
#  '2022.acl-long.190',
#  '2022.acl-long.191',
#  '2022.acl-long.192',
#  '2022.acl-long.193',
#  '2022.acl-long.194',
#  '2022.acl-long.195',
#  '2022.acl-long.196',
#  '2022.acl-long.197',
#  '2022.acl-long.198',
#  '2022.acl-long.199',
#  '2022.acl-long.2',
#  '2022.acl-long.20',
#  '2022.acl-long.200',
#  '2022.acl-long.201',
#  '2022.acl-long.202',
#  '2022.acl-long.203',
#  '2022.acl-long.204',
#  '2022.acl-long.205',
#  '2022.acl-long.206',
#  '2022.acl-long.207',
#  '2022.acl-long.208',
#  '2022.acl-long.209',
#  '2022.acl-long.21',
#  '2022.acl-long.210',
#  '2022.acl-long.211',
#  '2022.acl-long.212',
#  '2022.acl-long.213',
#  '2022.acl-long.214',
#  '2022.acl-long.215',
#  '2022.acl-long.216',
#  '2022.acl-long.217',
#  '2022.acl-long.218',
#  '2022.acl-long.219',
#  '2022.acl-long.22',
#  '2022.acl-long.220',
#  '2022.acl-long.221',
#  '2022.acl-long.222',
#  '2022.acl-long.223',
#  '2022.acl-long.224',
#  '2022.acl-long.225',
#  '2022.acl-long.226',
#  '2022.acl-long.227',
#  '2022.acl-long.228',
#  '2022.acl-long.229',
#  '2022.acl-long.23',
#  '2022.acl-long.230',
#  '2022.acl-long.231',
#  '2022.acl-long.232',
#  '2022.acl-long.233',
#  '2022.acl-long.234',
#  '2022.acl-long.235',
#  '2022.acl-long.236',
#  '2022.acl-long.237',
#  '2022.acl-long.238',
#  '2022.acl-long.239',
#  '2022.acl-long.24',
#  '2022.acl-long.240',
#  '2022.acl-long.241',
#  '2022.acl-long.242',
#  '2022.acl-long.243',
#  '2022.acl-long.244',
#  '2022.acl-long.245',
#  '2022.acl-long.246',
#  '2022.acl-long.247',
#  '2022.acl-long.248',
#  '2022.acl-long.249',
#  '2022.acl-long.25',
#  '2022.acl-long.250',
#  '2022.acl-long.251',
#  '2022.acl-long.252',
#  '2022.acl-long.253',
#  '2022.acl-long.254',
#  '2022.acl-long.255',
#  '2022.acl-long.256',
#  '2022.acl-long.257',
#  '2022.acl-long.258',
#  '2022.acl-long.259',
#  '2022.acl-long.26',
#  '2022.acl-long.260',
#  '2022.acl-long.261',
#  '2022.acl-long.262',
#  '2022.acl-long.263',
#  '2022.acl-long.264',
#  '2022.acl-long.265',
#  '2022.acl-long.266',
#  '2022.acl-long.267',
#  '2022.acl-long.268',
#  '2022.acl-long.269',
#  '2022.acl-long.27',
#  '2022.acl-long.270',
#  '2022.acl-long.271',
#  '2022.acl-long.272',
#  '2022.acl-long.273',
#  '2022.acl-long.274',
#  '2022.acl-long.275',
#  '2022.acl-long.276',
#  '2022.acl-long.277',
#  '2022.acl-long.278',
#  '2022.acl-long.279',
#  '2022.acl-long.28',
#  '2022.acl-long.280',
#  '2022.acl-long.281',
#  '2022.acl-long.282',
#  '2022.acl-long.283',
#  '2022.acl-long.284',
#  '2022.acl-long.285',
#  '2022.acl-long.286',
#  '2022.acl-long.287',
#  '2022.acl-long.288',
#  '2022.acl-long.289',
#  '2022.acl-long.29',
#  '2022.acl-long.290',
#  '2022.acl-long.291',
#  '2022.acl-long.292',
#  '2022.acl-long.293',
#  '2022.acl-long.294',
#  '2022.acl-long.295',
#  '2022.acl-long.296',
#  '2022.acl-long.297',
#  '2022.acl-long.298',
#  '2022.acl-long.299',
#  '2022.acl-long.3',
#  '2022.acl-long.30',
#  '2022.acl-long.300',
#  '2022.acl-long.301',
#  '2022.acl-long.302',
#  '2022.acl-long.303',
#  '2022.acl-long.304',
#  '2022.acl-long.305',
#  '2022.acl-long.306',
#  '2022.acl-long.307',
#  '2022.acl-long.308',
#  '2022.acl-long.309',
#  '2022.acl-long.31',
#  '2022.acl-long.310',
#  '2022.acl-long.311',
#  '2022.acl-long.312',
#  '2022.acl-long.313',
#  '2022.acl-long.314',
#  '2022.acl-long.315',
#  '2022.acl-long.316',
#  '2022.acl-long.317',
#  '2022.acl-long.318',
#  '2022.acl-long.319',
#  '2022.acl-long.32',
#  '2022.acl-long.320',
#  '2022.acl-long.321',
#  '2022.acl-long.322',
#  '2022.acl-long.323',
#  '2022.acl-long.324',
#  '2022.acl-long.325',
#  '2022.acl-long.326',
#  '2022.acl-long.327',
#  '2022.acl-long.328',
#  '2022.acl-long.329',
#  '2022.acl-long.33',
#  '2022.acl-long.330',
#  '2022.acl-long.331',
#  '2022.acl-long.332',
#  '2022.acl-long.333',
#  '2022.acl-long.334',
#  '2022.acl-long.335',
#  '2022.acl-long.336',
#  '2022.acl-long.337',
#  '2022.acl-long.338',
#  '2022.acl-long.339',
#  '2022.acl-long.34',
#  '2022.acl-long.340',
#  '2022.acl-long.341',
#  '2022.acl-long.342',
#  '2022.acl-long.343',
#  '2022.acl-long.344',
#  '2022.acl-long.345',
#  '2022.acl-long.346',
#  '2022.acl-long.347',
#  '2022.acl-long.348',
#  '2022.acl-long.349',
#  '2022.acl-long.35',
#  '2022.acl-long.350',
#  '2022.acl-long.351',
#  '2022.acl-long.352',
#  '2022.acl-long.353',
#  '2022.acl-long.354',
#  '2022.acl-long.355',
#  '2022.acl-long.356',
#  '2022.acl-long.357',
#  '2022.acl-long.358',
#  '2022.acl-long.359',
#  '2022.acl-long.36',
#  '2022.acl-long.360',
#  '2022.acl-long.361',
#  '2022.acl-long.362',
#  '2022.acl-long.363',
#  '2022.acl-long.364',
#  '2022.acl-long.365',
#  '2022.acl-long.366',
#  '2022.acl-long.367',
#  '2022.acl-long.368',
#  '2022.acl-long.369',
#  '2022.acl-long.37',
#  '2022.acl-long.370',
#  '2022.acl-long.371',
#  '2022.acl-long.372',
#  '2022.acl-long.373',
#  '2022.acl-long.374',
#  '2022.acl-long.375',
#  '2022.acl-long.376',
#  '2022.acl-long.377',
#  '2022.acl-long.378',
#  '2022.acl-long.379',
#  '2022.acl-long.38',
#  '2022.acl-long.380',
#  '2022.acl-long.381',
#  '2022.acl-long.382',
#  '2022.acl-long.383',
#  '2022.acl-long.384',
#  '2022.acl-long.385',
#  '2022.acl-long.386',
#  '2022.acl-long.387',
#  '2022.acl-long.388',
#  '2022.acl-long.389',
#  '2022.acl-long.39',
#  '2022.acl-long.390',
#  '2022.acl-long.391',
#  '2022.acl-long.392',
#  '2022.acl-long.393',
#  '2022.acl-long.394',
#  '2022.acl-long.395',
#  '2022.acl-long.396',
#  '2022.acl-long.397',
#  '2022.acl-long.398',
#  '2022.acl-long.399',
#  '2022.acl-long.4',
#  '2022.acl-long.40',
#  '2022.acl-long.400',
#  '2022.acl-long.401',
#  '2022.acl-long.402',
#  '2022.acl-long.403',
#  '2022.acl-long.404',
#  '2022.acl-long.405',
#  '2022.acl-long.406',
#  '2022.acl-long.407',
#  '2022.acl-long.408',
#  '2022.acl-long.409',
#  '2022.acl-long.41',
#  '2022.acl-long.410',
#  '2022.acl-long.411',
#  '2022.acl-long.412',
#  '2022.acl-long.413',
#  '2022.acl-long.414',
#  '2022.acl-long.415',
#  '2022.acl-long.416',
#  '2022.acl-long.417',
#  '2022.acl-long.418',
#  '2022.acl-long.419',
#  '2022.acl-long.42',
#  '2022.acl-long.420',
#  '2022.acl-long.421',
#  '2022.acl-long.422',
#  '2022.acl-long.423',
#  '2022.acl-long.424',
#  '2022.acl-long.425',
#  '2022.acl-long.426',
#  '2022.acl-long.427',
#  '2022.acl-long.428',
#  '2022.acl-long.429',
#  '2022.acl-long.43',
#  '2022.acl-long.430',
#  '2022.acl-long.431',
#  '2022.acl-long.432',
#  '2022.acl-long.433',
#  '2022.acl-long.434',
#  '2022.acl-long.435',
#  '2022.acl-long.436',
#  '2022.acl-long.437',
#  '2022.acl-long.438',
#  '2022.acl-long.439',
#  '2022.acl-long.44',
#  '2022.acl-long.440',
#  '2022.acl-long.441',
#  '2022.acl-long.442',
#  '2022.acl-long.443',
#  '2022.acl-long.444',
#  '2022.acl-long.445',
#  '2022.acl-long.446',
#  '2022.acl-long.447',
#  '2022.acl-long.448',
#  '2022.acl-long.449',
#  '2022.acl-long.45',
#  '2022.acl-long.450',
#  '2022.acl-long.451',
#  '2022.acl-long.452',
#  '2022.acl-long.453',
#  '2022.acl-long.454',
#  '2022.acl-long.455',
#  '2022.acl-long.456',
#  '2022.acl-long.457',
#  '2022.acl-long.458',
#  '2022.acl-long.459',
#  '2022.acl-long.46',
#  '2022.acl-long.460',
#  '2022.acl-long.461',
#  '2022.acl-long.462',
#  '2022.acl-long.463',
#  '2022.acl-long.464',
#  '2022.acl-long.465',
#  '2022.acl-long.466',
#  '2022.acl-long.467',
#  '2022.acl-long.468',
#  '2022.acl-long.469',
#  '2022.acl-long.47',
#  '2022.acl-long.470',
#  '2022.acl-long.471',
#  '2022.acl-long.472',
#  '2022.acl-long.473',
#  '2022.acl-long.474',
#  '2022.acl-long.475',
#  '2022.acl-long.476',
#  '2022.acl-long.477',
#  '2022.acl-long.478',
#  '2022.acl-long.479',
#  '2022.acl-long.48',
#  '2022.acl-long.480',
#  '2022.acl-long.481',
#  '2022.acl-long.482',
#  '2022.acl-long.483',
#  '2022.acl-long.484',
#  '2022.acl-long.485',
#  '2022.acl-long.486',
#  '2022.acl-long.487',
#  '2022.acl-long.488',
#  '2022.acl-long.489',
#  '2022.acl-long.49',
#  '2022.acl-long.490',
#  '2022.acl-long.491',
#  '2022.acl-long.492',
#  '2022.acl-long.493',
#  '2022.acl-long.494',
#  '2022.acl-long.495',
#  '2022.acl-long.496',
#  '2022.acl-long.497',
#  '2022.acl-long.498',
#  '2022.acl-long.499',
#  '2022.acl-long.5',
#  '2022.acl-long.50',
#  '2022.acl-long.500',
#  '2022.acl-long.501',
#  '2022.acl-long.502',
#  '2022.acl-long.503',
#  '2022.acl-long.504',
#  '2022.acl-long.505',
#  '2022.acl-long.506',
#  '2022.acl-long.507',
#  '2022.acl-long.508',
#  '2022.acl-long.509',
#  '2022.acl-long.51',
#  '2022.acl-long.510',
#  '2022.acl-long.511',
#  '2022.acl-long.512',
#  '2022.acl-long.513',
#  '2022.acl-long.514',
#  '2022.acl-long.515',
#  '2022.acl-long.516',
#  '2022.acl-long.517',
#  '2022.acl-long.518',
#  '2022.acl-long.519',
#  '2022.acl-long.52',
#  '2022.acl-long.520',
#  '2022.acl-long.521',
#  '2022.acl-long.522',
#  '2022.acl-long.523',
#  '2022.acl-long.524',
#  '2022.acl-long.525',
#  '2022.acl-long.526',
#  '2022.acl-long.527',
#  '2022.acl-long.528',
#  '2022.acl-long.529',
#  '2022.acl-long.53',
#  '2022.acl-long.530',
#  '2022.acl-long.531',
#  '2022.acl-long.532',
#  '2022.acl-long.533',
#  '2022.acl-long.534',
#  '2022.acl-long.535',
#  '2022.acl-long.536',
#  '2022.acl-long.537',
#  '2022.acl-long.538',
#  '2022.acl-long.539',
#  '2022.acl-long.54',
#  '2022.acl-long.540',
#  '2022.acl-long.541',
#  '2022.acl-long.542',
#  '2022.acl-long.543',
#  '2022.acl-long.544',
#  '2022.acl-long.545',
#  '2022.acl-long.546',
#  '2022.acl-long.547',
#  '2022.acl-long.548',
#  '2022.acl-long.549',
#  '2022.acl-long.55',
#  '2022.acl-long.550',
#  '2022.acl-long.551',
#  '2022.acl-long.552',
#  '2022.acl-long.553',
#  '2022.acl-long.554',
#  '2022.acl-long.555',
#  '2022.acl-long.556',
#  '2022.acl-long.557',
#  '2022.acl-long.558',
#  '2022.acl-long.559',
#  '2022.acl-long.56',
#  '2022.acl-long.560',
#  '2022.acl-long.561',
#  '2022.acl-long.562',
#  '2022.acl-long.563',
#  '2022.acl-long.564',
#  '2022.acl-long.565',
#  '2022.acl-long.566',
#  '2022.acl-long.567',
#  '2022.acl-long.568',
#  '2022.acl-long.569',
#  '2022.acl-long.57',
#  '2022.acl-long.570',
#  '2022.acl-long.571',
#  '2022.acl-long.572',
#  '2022.acl-long.573',
#  '2022.acl-long.574',
#  '2022.acl-long.575',
#  '2022.acl-long.576',
#  '2022.acl-long.577',
#  '2022.acl-long.578',
#  '2022.acl-long.579',
#  '2022.acl-long.58',
#  '2022.acl-long.580',
#  '2022.acl-long.581',
#  '2022.acl-long.582',
#  '2022.acl-long.583',
#  '2022.acl-long.584',
#  '2022.acl-long.585',
#  '2022.acl-long.586',
#  '2022.acl-long.587',
#  '2022.acl-long.588',
#  '2022.acl-long.589',
#  '2022.acl-long.59',
#  '2022.acl-long.590',
#  '2022.acl-long.591',
#  '2022.acl-long.592',
#  '2022.acl-long.593',
#  '2022.acl-long.594',
#  '2022.acl-long.595',
#  '2022.acl-long.596',
#  '2022.acl-long.597',
#  '2022.acl-long.598',
#  '2022.acl-long.599',
#  '2022.acl-long.6',
#  '2022.acl-long.60',
#  '2022.acl-long.600',
#  '2022.acl-long.601',
#  '2022.acl-long.602',
#  '2022.acl-long.603',
#  '2022.acl-long.61',
#  '2022.acl-long.62',
#  '2022.acl-long.63',
#  '2022.acl-long.64',
#  '2022.acl-long.65',
#  '2022.acl-long.66',
#  '2022.acl-long.67',
#  '2022.acl-long.68',
#  '2022.acl-long.69',
#  '2022.acl-long.7',
#  '2022.acl-long.70',
#  '2022.acl-long.71',
#  '2022.acl-long.72',
#  '2022.acl-long.73',
#  '2022.acl-long.74',
#  '2022.acl-long.75',
#  '2022.acl-long.76',
#  '2022.acl-long.77',
#  '2022.acl-long.78',
#  '2022.acl-long.79',
#  '2022.acl-long.8',
#  '2022.acl-long.80',
#  '2022.acl-long.81',
#  '2022.acl-long.82',
#  '2022.acl-long.83',
#  '2022.acl-long.84',
#  '2022.acl-long.85',
#  '2022.acl-long.86',
#  '2022.acl-long.87',
#  '2022.acl-long.88',
#  '2022.acl-long.89',
#  '2022.acl-long.9',
#  '2022.acl-long.90',
#  '2022.acl-long.91',
#  '2022.acl-long.92',
#  '2022.acl-long.93',
#  '2022.acl-long.94',
#  '2022.acl-long.95',
#  '2022.acl-long.96',
#  '2022.acl-long.97',
#  '2022.acl-long.98',
#  '2022.acl-long.99',
#  '2022.acl-short.1',
#  '2022.acl-short.10',
#  '2022.acl-short.11',
#  '2022.acl-short.12',
#  '2022.acl-short.13',
#  '2022.acl-short.14',
#  '2022.acl-short.15',
#  '2022.acl-short.16',
#  '2022.acl-short.17',
#  '2022.acl-short.18',
#  '2022.acl-short.19',
#  '2022.acl-short.2',
#  '2022.acl-short.20',
#  '2022.acl-short.21',
#  '2022.acl-short.22',
#  '2022.acl-short.23',
#  '2022.acl-short.24',
#  '2022.acl-short.25',
#  '2022.acl-short.26',
#  '2022.acl-short.27',
#  '2022.acl-short.28',
#  '2022.acl-short.29',
#  '2022.acl-short.3',
#  '2022.acl-short.30',
#  '2022.acl-short.31',
#  '2022.acl-short.32',
#  '2022.acl-short.33',
#  '2022.acl-short.34',
#  '2022.acl-short.35',
#  '2022.acl-short.36',
#  '2022.acl-short.37',
#  '2022.acl-short.38',
#  '2022.acl-short.39',
#  '2022.acl-short.4',
#  '2022.acl-short.40',
#  '2022.acl-short.41',
#  '2022.acl-short.42',
#  '2022.acl-short.43',
#  '2022.acl-short.44',
#  '2022.acl-short.45',
#  '2022.acl-short.46',
#  '2022.acl-short.47',
#  '2022.acl-short.48',
#  '2022.acl-short.49',
#  '2022.acl-short.5',
#  '2022.acl-short.50',
#  '2022.acl-short.51',
#  '2022.acl-short.52',
#  '2022.acl-short.53',
#  '2022.acl-short.54',
#  '2022.acl-short.55',
#  '2022.acl-short.56',
#  '2022.acl-short.57',
#  '2022.acl-short.58',
#  '2022.acl-short.59',
#  '2022.acl-short.6',
#  '2022.acl-short.60',
#  '2022.acl-short.61',
#  '2022.acl-short.62',
#  '2022.acl-short.63',
#  '2022.acl-short.64',
#  '2022.acl-short.65',
#  '2022.acl-short.66',
#  '2022.acl-short.67',
#  '2022.acl-short.68',
#  '2022.acl-short.69',
#  '2022.acl-short.7',
#  '2022.acl-short.70',
#  '2022.acl-short.71',
#  '2022.acl-short.72',
#  '2022.acl-short.73',
#  '2022.acl-short.74',
#  '2022.acl-short.75',
#  '2022.acl-short.76',
#  '2022.acl-short.77',
#  '2022.acl-short.78',
#  '2022.acl-short.79',
#  '2022.acl-short.8',
#  '2022.acl-short.80',
#  '2022.acl-short.81',
#  '2022.acl-short.82',
#  '2022.acl-short.83',
#  '2022.acl-short.84',
#  '2022.acl-short.85',
#  '2022.acl-short.86',
#  '2022.acl-short.87',
#  '2022.acl-short.88',
#  '2022.acl-short.89',
#  '2022.acl-short.9',
#  '2022.acl-short.90',
#  '2022.acl-short.91',
#  '2022.acl-short.92',
#  '2022.acl-short.93',
#  '2022.acl-short.94',
#  '2022.acl-short.95',
#  '2022.acl-short.96',
#  '2022.acl-short.97',
#  '2022.acl-srw.1',
#  '2022.acl-srw.10',
#  '2022.acl-srw.11',
#  '2022.acl-srw.12',
#  '2022.acl-srw.13',
#  '2022.acl-srw.14',
#  '2022.acl-srw.15',
#  '2022.acl-srw.16',
#  '2022.acl-srw.17',
#  '2022.acl-srw.18',
#  '2022.acl-srw.19',
#  '2022.acl-srw.2',
#  '2022.acl-srw.20',
#  '2022.acl-srw.21',
#  '2022.acl-srw.22',
#  '2022.acl-srw.23',
#  '2022.acl-srw.24',
#  '2022.acl-srw.25',
#  '2022.acl-srw.26',
#  '2022.acl-srw.27',
#  '2022.acl-srw.28',
#  '2022.acl-srw.29',
#  '2022.acl-srw.3',
#  '2022.acl-srw.30',
#  '2022.acl-srw.31',
#  '2022.acl-srw.32',
#  '2022.acl-srw.33',
#  '2022.acl-srw.34',
#  '2022.acl-srw.35',
#  '2022.acl-srw.36',
#  '2022.acl-srw.37',
#  '2022.acl-srw.38',
#  '2022.acl-srw.39',
#  '2022.acl-srw.4',
#  '2022.acl-srw.5',
#  '2022.acl-srw.6',
#  '2022.acl-srw.7',
#  '2022.acl-srw.8',
#  '2022.acl-srw.9',
#  '2022.acl-tutorials.1',
#  '2022.acl-tutorials.2',
#  '2022.acl-tutorials.3',
#  '2022.acl-tutorials.4',
#  '2022.acl-tutorials.5',
#  '2022.acl-tutorials.6',
#  '2022.acl-tutorials.7',
#  '2022.acl-tutorials.8',
#  'P00-1022',
#  'P03-1042',
#  'P08-2006',
#  'P16-3001',
#  'P16-3002',
#  'P16-3003',
#  'P16-3004',
#  'P16-3005',
#  'P16-3006',
#  'P16-3007',
#  'P16-3008',
#  'P16-3009',
#  'P16-3010',
#  'P16-3011',
#  'P16-3012',
#  'P16-3013',
#  'P16-3014',
#  'P16-3015',
#  'P16-3016',
#  'P16-3017',
#  'P16-3018',
#  'P16-3019',
#  'P16-3020',
#  'P16-3021',
#  'P16-3022',
#  'P16-4001',
#  'P16-4002',
#  'P16-4003',
#  'P16-4004',
#  'P16-4005',
#  'P16-4006',
#  'P16-4007',
#  'P16-4008',
#  'P16-4009',
#  'P16-4010',
#  'P16-4011',
#  'P16-4012',
#  'P16-4013',
#  'P16-4014',
#  'P16-4015',
#  'P16-4016',
#  'P16-4017',
#  'P16-4018',
#  'P16-4019',
#  'P16-4020',
#  'P16-4021',
#  'P16-4022',
#  ...]

# %% [markdown]
# #### Step 3 初步检索

# %%
def get_reference_paper_id(paper_id):

    reference_lists = []
    base_url = f"https://api.openalex.org/works/https://doi.org/10.18653/v1/{paper_id}"

    response = requests.get(base_url)
    response_json = response.json()
    try:
        reference_lists = response_json['referenced_works']
    except Exception as e:
        print(f'reference出错了{e}')

    return reference_lists

# %%
def get_paper_instution_author(reference_url_id):
    author_lists = []
    institution_lists = []
    type_lists = []
    base_url = f"https://api.openalex.org/{reference_url_id}" + "&mailto=1146904101@qq.com"

    response = requests.get(base_url)
    response_json = response.json()
    title = response_json['title']
    try:
        for item in response_json['authorships']:
            author_lists.append(item['author']['display_name'])

            if item['institutions'] == []:
                publication_year = response_json['publication_year']
                author_id = item['author']['id'].split('/')[-1]
                author_url = f"https://api.openalex.org/people/{author_id}"
                response = requests.get(author_url)
                for affi_list in response.json()["affiliations"]:
                    if publication_year in affi_list['years']:

                        institution_lists.append(affi_list['institution']['display_name'])
                        type_lists.append(affi_list['institution']['type'])
                        break
                # 使用最早的机构
                else:
                    try:
                        affi_list_json = response.json()["affiliations"][-1]
                        institution_lists.append(affi_list_json['institution']['display_name'])
                        type_lists.append(affi_list_json['institution']['type'])
                    except:
                        continue
            else:

                institution_lists.append(item['institutions'][0]['display_name'])
                type_lists.append(item['institutions'][0]['type'])
    except Exception as e:
        print(f'institution出错了{e}')

    return title, author_lists, institution_lists, type_lists

# %% [markdown]
# #### Step 4 写入Excel

# %%
import openpyxl
from tqdm import tqdm

# 创建一个新的 Excel 文件
output_wb = openpyxl.Workbook()
output_ws = output_wb.active

# 写入表头
output_ws.append(['Paper_ID', 'Title', 'Author_Name', 'Institution_Name', 'Institution_Type'])

# 初始化计数器
counter = 0

# 在 tqdm 循环中处理每一行，并将结果逐行写入新的 Excel 文件
for paper_id in tqdm(rest_paper_id):

    reference_lists = get_reference_paper_id(paper_id)
    for reference_id in reference_lists:
        title, author_lists, institution_lists, type_lists = get_paper_instution_author(reference_id)

        output_ws.append([paper_id, title, str(author_lists), str(institution_lists), str(type_lists)])

        # 更新计数器
        counter += 1

        # 如果计数器达到5000的倍数，保存文件并重置计数器
        if counter % 50 == 0:
            output_wb.save('12345.xlsx')
            print('保存了一个')

# 最后保存文件
output_wb.save('12345.xlsx')
# Out:
#   0%|          | 6/3161 [01:50<17:18:16, 19.75s/it]
# 保存了一个
#   0%|          | 6/3161 [02:37<23:01:00, 26.26s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 19
#      17 reference_lists = get_reference_paper_id(paper_id)
#      18 for reference_id in reference_lists:
# ---> 19     title, author_lists, institution_lists, type_lists = get_paper_instution_author(reference_id)
#      21     output_ws.append([paper_id, title, str(author_lists), str(institution_lists), str(type_lists)])
#      23     # 更新计数器
#
# Cell In[14], line 18, in get_paper_instution_author(reference_url_id)
#      16 author_id = item['author']['id'].split('/')[-1]
#      17 author_url = f"https://api.openalex.org/people/{author_id}"
# ---> 18 response = requests.get(author_url)
#      19 for affi_list in response.json()["affiliations"]:
#      20     if publication_year in affi_list['years']:
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File d:\Anaconda\envs\my_torch\Lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File d:\Anaconda\envs\my_torch\Lib\http\client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File d:\Anaconda\envs\my_torch\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File d:\Anaconda\envs\my_torch\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File d:\Anaconda\envs\my_torch\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File d:\Anaconda\envs\my_torch\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File d:\Anaconda\envs\my_torch\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
url = 'https://aclanthology.org/search/?q=https://aclanthology.org/A00-3001'
response = requests.get(url)

# %%
response.encoding = 'utf-8'
response.text
# Out:
# '<!doctype html><html lang=en-us><head><meta charset=utf-8><meta charset=utf-8><meta name=viewport content="width=device-width,initial-scale=1,shrink-to-fit=no"><!--[if IEMobile]><meta http-equiv=cleartype content="on"><![endif]--><title>Search Results - ACL Anthology</title><meta name=generator content="Hugo 0.118.2"><link href=/aclicon.ico rel="shortcut icon" type=image/x-icon><link rel=stylesheet href=/css/main.min.b1d14a9a8f6bb9c608ca4de9aad72a6e06945119f97951f2908522dc220e6277.css media=screen><link rel=stylesheet href=https://use.fontawesome.com/releases/v5.7.2/css/all.css integrity=sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr crossorigin=anonymous><link rel=stylesheet href=/css/academicons.min.css><meta name=robots content="noindex, nofollow"></head><body><nav class="navbar navbar-expand-sm navbar-light bg-light bg-gradient-light shadow-sm py-0 mb-3 mb-md-4 mb-xl-5"><div id=navbar-container class=container><a class=navbar-brand href=/><img src=/images/acl-logo.svg width=56 alt="ACL Logo">\n<span class="d-inline pl-2">ACL Anthology</span></a>\n<button class=navbar-toggler type=button data-toggle=collapse data-target=#navbarSupportedContent aria-controls=navbarSupportedContent aria-expanded=false aria-label="Toggle navigation">\n<span class=navbar-toggler-icon></span></button><div class="collapse navbar-collapse" id=navbarSupportedContent><ul class="navbar-nav flex-grow-1 pr-md-2"><li class=nav-item><a class=nav-link href=/posts/>News<span class=sr-only>(current)</span></a></li><li class=nav-item><a class=nav-link href=/faq/>FAQ<span class=sr-only>(current)</span></a></li><li class=nav-item><a class=nav-link href=/info/corrections/>Corrections<span class=sr-only>(current)</span></a></li><li class=nav-item><a class=nav-link href=/info/contrib/>Submissions<span class=sr-only>(current)</span></a></li><li class=nav-item><a class=nav-link href=https://github.com/acl-org/acl-anthology/><i class="fab fa-github pr-1"></i>Github</a></li></ul><form class="form-inline my-2 my-lg-0 flex-nowrap" action=/search/? method=get><input id=acl-search-box class="form-control mr-sm-2" name=q type=search placeholder=Search... aria-label=Search>\n<button class="btn btn-outline-primary" type=submit><i class="fas fa-search"></i></button></form></div></div></nav><div id=main-container class=container><main aria-role=main><button class="btn btn-info float-right" type=button data-toggle=collapse data-target=#collapseHelp aria-expanded=false aria-controls=collapseHelp>\n<i class="fas fa-info-circle mr-2"></i>How does the search work?</button><h2 id=title>Search Results</h2><hr><div class=collapse id=collapseHelp><div class="card bg-light"><div class=card-body><h5 class=card-title>How does the search work?</h5><p class=card-text>The search results you see here are provided by <a href=https://developers.google.com/custom-search/>Google Custom Search.</a> As such, they rely on Google having indexed our pages; this means that pages that have recently been added or changed might not be accurately represented in the search results until Google\'s crawler indexes them.</p><hr><h5 class=card-title>What do the different tabs mean?</h5><p class=card-text>By default, the search is performed on “All” Anthology content, which includes searching in PDFs hosted by the Anthology. By clicking on another tab, you can restrict the search to certain parts of the website:<ul><li>“Authors” restricts the search to author pages. For example, <a href=/people/m/matt-post/>“Matt Post”</a> is an author page.</li><li>“Events” restricts the search to event pages. For example, <a href=/events/acl-2018>“ACL 2018”</a> is an event page.</li><li>“Paper Metadata” restricts the search to pages for specific papers. For example, <a href=/papers/P/P02/P02-1040/>P02-1040</a> is a paper page. (Most notably, this does <em>not</em> search in PDFs.)</li></ul>Note that this will still find <em>any</em> string that appears on such a page; it is not currently possible to  ...
